# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanCamiloGB/Signals-and-Systems/blob/master/Taller01/3.%20Se%C3%B1ales%20de%20Energia%20y%20Potencia/a)_Se%C3%B1ales_cuaderno_Se%C3%B1ales_de_energia_y_potencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Ejercicio 1
#
# Graficar la potencia media de una impedancia $R+jwL$, cuándo es excitada por una fuente sinusoidal.
#
# Graficar la potencia media de una impedancia $R-j\frac{1}{wC} $, cuándo es excitada por una fuente sinusoidal.

# %%
import numpy as np
from numpy import matlib as mb
import matplotlib.pyplot as plt
import sympy as sym
from sympy import exp
from sympy import Symbol
from sympy import *
sym.init_printing()

# %%
#tomamos los valores de R,w,T0,Imax y N son los mismos para ambos ejercicios 
R= 4
w= 300
Imax = 2
T0 = 2*np.pi/w
N = 100
t = np.linspace(0, T0, N)

# %%
"""Solución Para R+jwL"""
L= 0.01
Vmax=np.sqrt(np.square(R)+np.square(w*L))*Imax
theta=np.arctan(w*L/R)
i=Imax*np.sin(w*t)
v=Vmax*np.sin(w*t+theta)

p=v*i #potencia instantanea
Pmed=1/T0*np.trapz(p, t)
print("Potencia media: "+str(P_med))

#plotear la corriente y la tensión
plt.figure(figsize=[20,5])
plt.subplot(131)
plt.plot(t, i, label = "i(t)")
plt.plot(t, v, label = "v(t)")
plt.xlabel('t')
plt.ylabel('Amplitud')
plt.grid()
plt.legend()
plt.subplot(132)
plt.plot(t,p,label = "Potencia instantanea p(t)")
plt.plot(t, Pmed*np.ones(len(t)),"r", label = "Potencia media P")
plt.xlabel('t')
plt.ylabel('Amplitud')
plt.grid()
plt.legend()
plt.show()
# Out:
# Potencia media: 10.0

# %%
"""Solución para R-j1/wc"""
C=0.01
Vmax=sym.sqrt(np.square(R)+np.square(1/w*C))*Imax
theta=-np.arctan(1/w*C*R)
i=Imax*np.sin(w*t)
v=Vmax*np.sin(w*t+theta)

p=v*i #potencia instantanea
P = np.trapz(p, t)/T0 #Potencia media
print("Potencia media: "+str(P))

plt.figure(figsize=[20,5])
plt.subplot(131)
plt.plot(t, i, label = "i(t)")
plt.plot(t, v, label = "v(t)")
plt.xlabel('t')
plt.ylabel('Amplitud')
plt.grid()
plt.legend()
plt.subplot(132)
plt.plot(t, p, label = "Potencia instantanea p(t)")
plt.plot(t, P*np.ones(len(t)), "r", label = "Potencia media P")
plt.xlabel('t')
plt.ylabel('Amplitud')
plt.grid()
plt.legend()
plt.show()
# Out:
# Potencia media: 7.99999992916667
