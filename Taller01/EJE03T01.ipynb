# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanCamiloGB/Signals-and-Systems/blob/master/EJE03T01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EJERCICIO
# Agregar otro escalón al principio de la señal escalera modificando el ejemplo anterior.

# %%
# %matplotlib inline
import sympy as sym
import matplotlib.pyplot as plt

t = sym.symbols('t', real=True) #se declara la variable simbólica t

# %%
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
sym.plot(rect, xlim=[-2,2], ylabel = r'rect(t)')

#el Ejemplo anterior
x = rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)
sym.plot(x, (t, -1, 5), ylim=[-0.2, 1.2], ylabel='$x(t)$');  
#Ejercicio
x2 = 4/3*rect.subs(t,t+1/2) + 1*rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2) 
sym.plot(x2, (t, -2, 5), ylim=[-0.5, 1.5], ylabel='$x(t)$');
