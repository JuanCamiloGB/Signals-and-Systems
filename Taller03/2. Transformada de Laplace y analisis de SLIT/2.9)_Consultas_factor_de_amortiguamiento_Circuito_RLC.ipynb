# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanCamiloGB/Signals-and-Systems/blob/master/Taller03/2.%20Transformada%20de%20Laplace%20y%20analisis%20de%20SLIT/2.9)_Consultas_factor_de_amortiguamiento_Circuito_RLC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**2.9 Consulte en que consiste un sistema subamortiguado, sobreamortiguado, y de amortiguamiento critico. Genere simulaciones para ejemplificar cada uno de los casos con los sistemas R,L,C serie y paralelo estudiados.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **PARA SISTEMAS RLC SERIE**
#
# Dado que es un circuito RLC serie su factor de amortiguamiento esta dado por la siguiente ecuación:
# $\zeta=\frac{R}{2\sqrt{\frac{L}{C}}}$

# %% [markdown]
# ##**SISTEMA SUBAMORTIGUADO**
#
# ###Para que el sistema sea subamortiguado $0<ζ<1$
#
# En este caso se tomaron los valores $R = 0.55 Ω , L = 0.6H, C = 0.5μF$. Para un $\zeta=0.5$
# \
# $$0< 0.5 < 1$$

# %%
import sympy as sym
import matplotlib.pyplot as plt  
sym.init_printing()

S = sym.symbols('S', complex=True)
t, R, L , C = sym.symbols('t R L C', positive=True )
#Entrada Laplace 
V_i = 1/S #Señal de entrada
H_s = (1/L*C)/(S**2 + (R/L)*S + 1/(L*C))  #Funcion de transferencia
V_c = H_s*V_i #Señal de Salida
V_c
#Función de salida en Laplace factorizada (fracciones parciales)
Y_p = V_c.apart(S) # apart factoriza la expresión 
Y_p
#RLC en funcion del tiempo
Y_e = Y_p
#Modelo en el tiempo con RLC evaluados
RLC1 = {R:sym.Rational('.55') , L: sym.Rational('.6'), C: sym.Rational('2')}#valores utilizados para la simulación
Y_e = Y_p.subs(RLC1)
for j in range(len(Y_e.args)):
    if j==0:
      yt = sym.inverse_laplace_transform(Y_e.args[j], S, t)
    else:
      yt+= sym.inverse_laplace_transform(Y_e.args[j], S, t)

#Gráfica de salida en el tiempo
sym.plot(yt, (t, 0,17), xlabel='$t$', ylabel='$y(t)$',line_color='k',title="RLC Subamortiguado")
plt.show()

# %% [markdown]
# ##**SISTEMA CRITICO**
#
# ####Para que el sistema sea criticamente amortiguado ζ=1
#
# Se tomaron los valores de $R= 4Ω, L=8mH , C=2μF$ para un $\zeta=1$

# %%
import sympy as sym
import matplotlib.pyplot as plt  
sym.init_printing()

S = sym.symbols('S', complex=True)
t, R, L , C = sym.symbols('t R L C', positive=True )
#Entrada Laplace 
V_i = 1/S #Señal de entrada
H_s = (1/L*C)/(S**2 + (R/L)*S + 1/(L*C)) #Funcion de transferencia
V_c = H_s*V_i #Señal de Salida
V_c
#Función de salida en Laplace factorizada (fracciones parciales)
Y_p = V_c.apart(S) # apart factoriza la expresión 
Y_p
#RLC en funcion del tiempo
Y_e = Y_p
#Modelo en el tiempo con RLC evaluados
RLC1 = {R:sym.Rational('4') , L: sym.Rational('8'), C: sym.Rational('2')}#valores utilizados para la simulación
Y_e = Y_p.subs(RLC1)
for j in range(len(Y_e.args)):
    if j==0:
      yt = sym.inverse_laplace_transform(Y_e.args[j], S, t)
    else:
      yt+= sym.inverse_laplace_transform(Y_e.args[j], S, t)

#Gráfica de salida en el tiempo
sym.plot(yt, (t, 0,50), xlabel='$t$', ylabel='$y(t)$',line_color='k',title="RLC Critico")
plt.show()

# %% [markdown]
# ##**SISTEMA SOBREAMORTIGUADO**
#
# ####Para que el sistema sea sobreamortiguado $ζ>1$
#
# Se tomaron los valores de $R= 25.6Ω, L=10mH , C=3μF$. para un $\zeta=7$

# %%
import sympy as sym
import matplotlib.pyplot as plt  
sym.init_printing()

S = sym.symbols('S', complex=True)
t, R, L , C = sym.symbols('t R L C', positive=True )
#Entrada Laplace 
V_i = 1/S #Señal de entrada
H_s = (1/L*C)/(S**2 + (R/L)*S + 1/(L*C)) #Funcion de transferencia
V_c = H_s*V_i #Señal de Salida
V_c
#Función de salida en Laplace factorizada (fracciones parciales)
Y_p = V_c.apart(S) # apart factoriza la expresión 
Y_p
#RLC en funcion del tiempo
Y_e = Y_p
#Modelo en el tiempo con RLC evaluados
RLC1 = {R:sym.Rational('25.6') , L: sym.Rational('10'), C: sym.Rational('3')}#valores utilizados para la simulación
Y_e = Y_p.subs(RLC1)
for j in range(len(Y_e.args)):
    if j==0:
      yt = sym.inverse_laplace_transform(Y_e.args[j], S, t)
    else:
      yt+= sym.inverse_laplace_transform(Y_e.args[j], S, t)

#Gráfica de salida en el tiempo
sym.plot(yt, (t, 0,280), xlabel='$t$', ylabel='$y(t)$',line_color='k',title="RLC Sobreamortiguado")
plt.show()

# %% [markdown]
# ##***Sistema Inestable***
#
# En este caso zeta tiene que ser menor a 0, es decir tener un valor negativo, asi que en la vida real esto no será posible, puesto que no hay resistencias, capacitores ni inductores que posean valores negativos.

# %% [markdown]
# # **PARA SISTEMAS RLC PARALELO**
# Dado que es un circuito RLC paralelo su factor de amortiguamiento esta dado por la siguiente ecuación: $\zeta=\frac{1}{2R\sqrt{\frac{C}{L}}}$

# %% [markdown]
# ##**SISTEMA SUBAMORTIGUADO**
#
# ###Para que el sistema sea subamortiguado $0<ζ<1$
#
# En este caso se tomaron los valores $R = 0.55 Ω , L = 0.6H, C = 0.5μF$. Para un $\zeta=0.5$

# %%
import sympy as sym
import matplotlib.pyplot as plt  
sym.init_printing()

S = sym.symbols('S', complex=True)
t, R, L , C = sym.symbols('t R L C', positive=True )
#Entrada Laplace 
V_i = 1/S #Señal de entrada
H_s = 1/(C*L*S**2 + (L/R)*S + 1) #Funcion de transferencia
V_c = H_s*V_i #Señal de Salida
V_c
#Función de salida en Laplace factorizada (fracciones parciales)
Y_p = V_c.apart(S) # apart factoriza la expresión 
Y_p
#RLC en funcion del tiempo
Y_e = Y_p
#Modelo en el tiempo con RLC evaluados
RLC1 = {R:sym.Rational('.55') , L: sym.Rational('.6'), C: sym.Rational('2')}#valores utilizados para la simulación
Y_e = Y_p.subs(RLC1)
for j in range(len(Y_e.args)):
    if j==0:
      yt = sym.inverse_laplace_transform(Y_e.args[j], S, t)
    else:
      yt+= sym.inverse_laplace_transform(Y_e.args[j], S, t)

#Gráfica de salida en el tiempo
sym.plot(yt, (t, 0,50), xlabel='$t$', ylabel='$y(t)$',line_color='k',title="RLC Subamortiguado")
plt.show()

# %% [markdown]
# ##**SISTEMA CRITICO**
#
# ####Para que el sistema sea criticamente amortiguado ζ=1
#
# Se tomaron los valores de $R= 4Ω, L=64mH , C=1μF$ para un $\zeta=1$

# %%
import sympy as sym
import matplotlib.pyplot as plt  
sym.init_printing()

S = sym.symbols('S', complex=True)
t, R, L , C = sym.symbols('t R L C', positive=True )
#Entrada Laplace 
V_i = 1/S #Señal de entrada
H_s = 1/(C*L*S**2 + (L/R)*S + 1) #Funcion de transferencia
V_c = H_s*V_i #Señal de Salida
V_c
#Función de salida en Laplace factorizada (fracciones parciales)
Y_p = V_c.apart(S) # apart factoriza la expresión 
Y_p
#RLC en funcion del tiempo
Y_e = Y_p
#Modelo en el tiempo con RLC evaluados
RLC1 = {R:sym.Rational('4') , L: sym.Rational('64'), C: sym.Rational('1')}#valores utilizados para la simulación
Y_e = Y_p.subs(RLC1)
for j in range(len(Y_e.args)):
    if j==0:
      yt = sym.inverse_laplace_transform(Y_e.args[j], S, t)
    else:
      yt+= sym.inverse_laplace_transform(Y_e.args[j], S, t)

#Gráfica de salida en el tiempo
sym.plot(yt, (t, 0,50), xlabel='$t$', ylabel='$y(t)$',line_color='k',title="RLC Critico")
plt.show()

# %% [markdown]
# ##**SISTEMA SOBREAMORTIGUADO**
#
# ####Para que el sistema sea sobreamortiguado $ζ>1$
#
# Se tomaron los valores de $R= 0.5Ω, L=10mH , C=3μF$. para un $\zeta=1.825$

# %%
import sympy as sym
import matplotlib.pyplot as plt  
sym.init_printing()

S = sym.symbols('S', complex=True)
t, R, L , C = sym.symbols('t R L C', positive=True )
#Entrada Laplace 
V_i = 1/S #Señal de entrada
H_s = 1/(C*L*S**2 + (L/R)*S + 1) #Funcion de transferencia
V_c = H_s*V_i #Señal de Salida
V_c
#Función de salida en Laplace factorizada (fracciones parciales)
Y_p = V_c.apart(S) # apart factoriza la expresión 
Y_p
#RLC en funcion del tiempo
Y_e = Y_p
#Modelo en el tiempo con RLC evaluados
RLC1 = {R:sym.Rational('.5') , L: sym.Rational('10'), C: sym.Rational('3')}#valores utilizados para la simulación
Y_e = Y_p.subs(RLC1)
for j in range(len(Y_e.args)):
    if j==0:
      yt = sym.inverse_laplace_transform(Y_e.args[j], S, t)
    else:
      yt+= sym.inverse_laplace_transform(Y_e.args[j], S, t)

#Gráfica de salida en el tiempo
sym.plot(yt, (t, 0,100), xlabel='$t$', ylabel='$y(t)$',line_color='k',title="RLC Sobreamortiguado")
plt.show()

# %% [markdown]
# ##***Sistema Inestable***
#
# En este caso zeta tiene que ser menor a 0, es decir tener un valor negativo, asi que en la vida real esto no será posible, puesto que no hay resistencias, capacitores ni inductores que posean valores negativos.
